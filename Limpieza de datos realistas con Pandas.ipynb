# %% [markdown]
# # Proyecto - Limpieza de datos realistas

# %% [markdown]
# Utilizando un codigo en Python, previamente se generó una base de datos realista para hacer limpieza.

# %%
# Importando librerias pandas y numpy
import pandas as pd
import numpy as np

# %%
# Localización absoluta de la libreta
import os
os.getcwd()
# Out:
# 'C:\\Users\\lego_\\Documents'

# %%
# Localizacion de los archivos
file_name1 = "C:\\Users\\lego_\\Documents\\orders_dirty.csv"
file_name2 = "C:\\Users\\lego_\\Documents\\products_dirty.csv"
file_name3 = "C:\\Users\\lego_\\Documents\\customers_dirty.csv"

# %% [markdown]
# <h2> Limpieza para la tabla "Orders" </h2>

# %%
#Data frame "orders"
df_ord = pd.read_csv(file_name1)
df_ord.head()
# Out:
#    order_id  customer_id  product_id  order_date  quantity   price  \
# 0         1          123           6  2023-03-31         1  355.49
# 1         2           27           3  2023-12-10         1  357.01
# 2         3          139          10  2023-12-16         2  134.30
# 3         4           73          16  2023-04-13         3  374.66
# 4         5          179           1  2023-10-25         2  300.03
#
#    total_amount
# 0        355.49
# 1        357.01
# 2        268.60
# 3       1123.98
# 4      30003.00

# %% [markdown]
# ### Primero cambiamos los titulos

# %%
#Cambiamos los títulos
df_ord.rename(columns = {'order_id':'Order_ID', 'customer_id':'Customer_ID', 'product_id':'Product_ID',
                         'order_date':'Order_date', 'quantity':'Quantity','price':'Price',
                         'total_amount':'Total_amount'})
# Out:
#       Order_ID  Customer_ID  Product_ID  Order_date  Quantity   Price  \
# 0            1          123           6  2023-03-31         1  355.49
# 1            2           27           3  2023-12-10         1  357.01
# 2            3          139          10  2023-12-16         2  134.30
# 3            4           73          16  2023-04-13         3  374.66
# 4            5          179           1  2023-10-25         2  300.03
# ...        ...          ...         ...         ...       ...     ...
# 2555      1285           39          18  2023-03-10         2  126.38
# 2556       238          180          11  2023-06-28         3  208.55
# 2557       636          216           7  2023-02-16         3  131.87
# 2558      1007          220           4  2023-03-15         1  246.02
# 2559      1375           18           5  2023-10-05         1  195.21
#
#       Total_amount
# 0           355.49
# 1           357.01
# 2           268.60
# 3          1123.98
# 4         30003.00
# ...            ...
# 2555        252.76
# 2556        625.65
# 2557        395.61
# 2558        246.02
# 2559        195.21
#
# [2560 rows x 7 columns]

# %%
#"orders" info
df_ord.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2560 entries, 0 to 2559
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      2560 non-null   int64
#  1   customer_id   2560 non-null   int64
#  2   product_id    2560 non-null   int64
#  3   order_date    2560 non-null   str
#  4   quantity      2560 non-null   int64
#  5   price         2560 non-null   float64
#  6   total_amount  2456 non-null   float64
# dtypes: float64(2), int64(4), str(1)
# memory usage: 140.1 KB

# %% [markdown]
# Con esto notamos que hay valores nulos en "Total_amount".

# %%
#"orders" tipos de dato
df_ord.dtypes
# Out:
# order_id          int64
# customer_id       int64
# product_id        int64
# order_date          str
# quantity          int64
# price           float64
# total_amount    float64
# dtype: object

# %%
#"orders" valores estadisticos
df_ord.describe()
# Out:
#           order_id  customer_id   product_id     quantity        price  \
# count  2560.000000  2560.000000  2560.000000  2560.000000  2560.000000
# mean   1247.458594   149.430469    10.275781     1.993359   222.041852
# std     721.041258    86.678566     5.771109     0.821955   126.224316
# min       1.000000     1.000000     1.000000     1.000000   -50.000000
# 25%     623.750000    72.000000     5.000000     1.000000   171.820000
# 50%    1247.500000   149.000000    10.000000     2.000000   208.550000
# 75%    1871.250000   226.000000    15.000000     3.000000   343.710000
# max    2500.000000   300.000000    20.000000     3.000000   413.170000
#
#        total_amount
# count   2456.000000
# mean     510.250619
# std     1491.996797
# min    -7500.000000
# 25%      222.880000
# 50%      390.420000
# 75%      668.640000
# max    41317.000000

# %% [markdown]
# Podemos notar que el máx en "total_amount" es mayor a 40000, cuando el precio más alto de un item es menor a 500 y la cantidad comprada es máximo 3, lo que es incosistente. También notamos que hay valores negativos en "price".

# %% [markdown]
# Buscamos los valores donde el precio es negativo:

# %%
df_ord.query("price < 0")
# Out:
#       order_id  customer_id  product_id  order_date  quantity  price  \
# 26          27           28          13  2023-08-25         2  -50.0
# 27          28          112          12  2023-09-16         2  -50.0
# 28          29          141          12  2023-12-09         2  -50.0
# 39          40           65          13  2023-08-19         1  -50.0
# 62          63           40          13  2026-01-01         3  -50.0
# ...        ...          ...         ...         ...       ...    ...
# 2511      1283          134          13  2023-05-16         3  -50.0
# 2514      1576            4          12  2023-02-28         3  -50.0
# 2531       633            9          12  2023-06-20         2  -50.0
# 2538       133          166          12  2023-03-08         1  -50.0
# 2540       202          136          12  2023-12-22         1  -50.0
#
#       total_amount
# 26          -100.0
# 27          -100.0
# 28          -100.0
# 39           -50.0
# 62          -150.0
# ...            ...
# 2511        -150.0
# 2514        -150.0
# 2531        -100.0
# 2538         -50.0
# 2540         -50.0
#
# [261 rows x 7 columns]

# %%
neg_vals = df_ord.query("price < 0")["product_id"]
neg_vals.unique()
# Out:
# array([13, 12])

# %%
df_ord.query('product_id in [12,13] and price>0')
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, product_id, order_date, quantity, price, total_amount]
# Index: []

# %% [markdown]
# Todos artículos con "product_id" 12 y 13 tienen precios negativos. A falta de más información, los removemos.

# %%
df_ord = df_ord.query('price>0')

# %% [markdown]
# Corregimos los valores en "total_amount".

# %%
df_ord['total_amount'] = df_ord['price']*df_ord['quantity']

# %% [markdown]
# Hemos realizamos el calculo correctamente.

# %% [markdown]
# Convertimos los datos de tipo "string" a "datatime":

# %%
df_ord["order_date"] = pd.to_datetime(df_ord["order_date"])

# %%
df_ord.dtypes
# Out:
# order_id                 int64
# customer_id              int64
# product_id               int64
# order_date      datetime64[us]
# quantity                 int64
# price                  float64
# total_amount           float64
# dtype: object

# %%
len(df_ord[df_ord["order_date"] > pd.Timestamp.today()])
# Out:
# 0

# %% [markdown]
# Consultamos las fechas posteriores a la fecha de hoy (2026-04-30), lo que muestra que <b>no</b> hay fechas con valores futuros

# %% [markdown]
# ### Buscamos los valores nulos y duplicados

# %%
df_ord.isna().sum()
# Out:
# order_id        0
# customer_id     0
# product_id      0
# order_date      0
# quantity        0
# price           0
# total_amount    0
# dtype: int64

# %% [markdown]
# No hay más valores faltantes en "total_amount". Buscamos valores duplicados:

# %%
df_ord.loc[df_ord.duplicated()]
# Out:
#       order_id  customer_id  product_id order_date  quantity   price  \
# 2500       507          250          15 2023-06-28         1  413.17
# 2502       355          117          18 2023-09-09         3  126.38
# 2503      1081           17           5 2023-01-02         1  195.21
# 2504      2390           72          17 2023-01-29         1  343.71
# 2549        343.71
# 2550        668.64
# 2551        222.88
# 2552        417.10
# 2553        749.32
# 2554        412.22
# 2555        252.76
# 2556        625.65
# 2557        395.61
# 2558        246.02
# 2559        195.21

# %%
df_ord.query('order_id == 507')
# Out:
#       order_id  customer_id  product_id order_date  quantity   price  \
# 506        507          250          15 2023-06-28         1  413.17
# 2500       507          250          15 2023-06-28         1  413.17
#
#       total_amount
# 506         413.17
# 2500        413.17

# %% [markdown]
# Notamos que hay filas duplicadas que no aportan información.

# %%
df_ord = df_ord.loc[~df_ord.duplicated()].reset_index(drop=True).copy()

# %% [markdown]
# Hemos guardado una copia que omite los valores duplicados.

# %% [markdown]
# La tabla "Orders" ha sido limpiada.

# %% [markdown]
# <h2> Limpieza para la tabla "Products" </h2>

# %%
#Data frame "products"
df_pr = pd.read_csv(file_name2)
df_pr.head()
# Out:
#    product_id    category   price
# 0           1  electrnics  300.03
# 1           2    Clothing  181.61
# 2           3        Home  357.01
# 3           4    Clothing  246.02
# 4           5    Clothing  195.21

# %%
#Información de la tabla de productos
df_pr.info
# Out:
# <bound method DataFrame.info of     product_id     category   price
# 0            1   electrnics  300.03
# 1            2     Clothing  181.61
# 2            3         Home  357.01
# 3            4     Clothing  246.02
# 4            5     Clothing  195.21
# 5            6   electrnics  355.49
# 6            7  Electronics  131.87
# 7            8  Electronics  171.82
# 8            9     Clothing  222.88
# 9           10         Home  134.30
# 10          11       Beauty  208.55
# 11          12       Beauty  -50.00
# 12          13  Electronics  -50.00
# 13          14  Electronics  385.93
# 14          15     Clothing  413.17
# 15          16       Beauty  374.66
# 16          17  Electronics  343.71
# 17          18         Home  126.38
# 18          19         Home  206.11
# 19          20  Electronics  244.08>

# %%
#tipos de dato en la tabla "productos"
df_pr.dtypes
# Out:
# product_id      int64
# category          str
# price         float64
# dtype: object

# %%
#Tamaño de la tabla 
df_pr.shape
# Out:
# (20, 3)

# %%
df_pr.describe(include=["str"])
# Out:
#         category
# count         18
# unique         5
# top     Clothing
# freq           5

# %%
df_pr.describe()
# Out:
#        product_id       price
# count    20.00000   20.000000
# mean     10.50000  224.941500
# std       5.91608  130.342052
# min       1.00000  -50.000000
# 25%       5.75000  162.440000
# 50%      10.50000  215.715000
# 75%      15.25000  346.655000
# max      20.00000  413.170000

# %% [markdown]
# Notamos que hay valores negativos en "price". Los eliminamos y reiniciamos los indices.

# %%
df_pr = df_pr[df_pr['price']>0]

# %%
df_pr.reset_index(drop=True)
# Out:
#     product_id     category   price
# 0            1   electrnics  300.03
# 1            2     Clothing  181.61
# 2            3         Home  357.01
# 3            4     Clothing  246.02
# 4            5     Clothing  195.21
# 5            6   electrnics  355.49
# 6            7  Electronics  131.87
# 7            8  Electronics  171.82
# 8            9     Clothing  222.88
# 9           10         Home  134.30
# 10          11       Beauty  208.55
# 11          14  Electronics  385.93
# 12          15     Clothing  413.17
# 13          16       Beauty  374.66
# 14          17  Electronics  343.71
# 15          18         Home  126.38
# 16          19         Home  206.11
# 17          20  Electronics  244.08

# %% [markdown]
# Revisamos qué nombres están mal escritos en "categorias".

# %%
df_pr['category'].value_counts()
# Out:
# category
# Clothing       5
# Electronics    5
# Home           4
# electrnics     2
# Beauty         2
# Name: count, dtype: int64

# %%
df_pr.replace({"electrnics":"Electronics"})
# Out:
#     product_id     category   price
# 0            1  Electronics  300.03
# 1            2     Clothing  181.61
# 2            3         Home  357.01
# 3            4     Clothing  246.02
# 4            5     Clothing  195.21
# 5            6  Electronics  355.49
# 6            7  Electronics  131.87
# 7            8  Electronics  171.82
# 8            9     Clothing  222.88
# 9           10         Home  134.30
# 10          11       Beauty  208.55
# 13          14  Electronics  385.93
# 14          15     Clothing  413.17
# 15          16       Beauty  374.66
# 16          17  Electronics  343.71
# 17          18         Home  126.38
# 18          19         Home  206.11
# 19          20  Electronics  244.08

# %%
#Data frame "custumers"
df_cus = pd.read_csv(file_name3)
df_cus.head()
# Out:
#    customer_id   country signup_date
# 0            1    Mexico  2023-09-27
# 1            2    Mexico  2023-06-11
# 2            3  Colombia  2023-07-08
# 3            4    Mexico  2023-09-04
# 4            5    Mexico  2023-08-04

# %%
#Información de la tabla de productos
df_cus.info
# Out:
# <bound method DataFrame.info of      customer_id   country signup_date
# 0              1    Mexico  2023-09-27
# 1              2    Mexico  2023-06-11
# 2              3  Colombia  2023-07-08
# 3              4    Mexico  2023-09-04
# 4              5    Mexico  2023-08-04
# ..           ...       ...         ...
# 295          296  Colombia  2023-11-07
# 296          297  Colombia  2023-10-29
# 297          298       USA  2023-02-01
# 298          299       USA  2023-02-24
# 299          300    Mexico  2023-12-18
#
# [300 rows x 3 columns]>

# %%
df_cus.dtypes
# Out:
# customer_id    int64
# country          str
# signup_date      str
# dtype: object

# %%
df_cus.shape
# Out:
# (300, 3)

# %%
df_cus.describe()
# Out:
#        customer_id
# count   300.000000
# mean    150.500000
# std      86.746758
# min       1.000000
# 25%      75.750000
# 50%     150.500000
# 75%     225.250000
# max     300.000000

# %%
df_cus.describe(include = ["str"])
# Out:
#        country signup_date
# count      290         300
# unique       4         208
# top     Mexico  2023-10-10
# freq       107           5

# %%
df_cus["country"].value_counts()
# Out:
# country
# Mexico      107
# Colombia     97
# USA          81
# Mx            5
# Name: count, dtype: int64

# %% [markdown]
# Estandarizamos los nombres de los paises:

# %%
df_cus.replace({"Mx":"Mexico"})
# Out:
#      customer_id   country signup_date
# 0              1    Mexico  2023-09-27
# 1              2    Mexico  2023-06-11
# 2              3  Colombia  2023-07-08
# 3              4    Mexico  2023-09-04
# 4              5    Mexico  2023-08-04
# ..           ...       ...         ...
# 295          296  Colombia  2023-11-07
# 296          297  Colombia  2023-10-29
# 297          298       USA  2023-02-01
# 298          299       USA  2023-02-24
# 299          300    Mexico  2023-12-18
#
# [300 rows x 3 columns]

# %%
df_cus["signup_date"].value_counts()
# Out:
# signup_date
# 2023-10-10    5
# 2023-03-24    4
# 2023-12-04    4
# 2023-03-14    4
# 2023-06-17    3
#              ..
# 2023-02-21    1
# 2023-12-10    1
# 2023-10-29    1
# 2023-02-01    1
# 2023-02-24    1
# Name: count, Length: 208, dtype: int64

# %% [markdown]
# Verificamos que no haya fechas incorrectas:

# %%
df_cus["signup_date"] = pd.to_datetime(df_cus["signup_date"])

# %%
len(df_cus[df_cus["signup_date"] > pd.Timestamp.today()])
# Out:
# 0

# %% [markdown]
# No hay fechas inconsistentes
